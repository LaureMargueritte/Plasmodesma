# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import Analyse
from Analyse import *

# %%
Analyse.NETMODE = 'mieux'
# Charger le fichier et ajouter les fonctions nettoie et symetrise :  "[...].csv", net=True, sym=True)
Imref = loadStd2D(r'ARTEnew\Results\ARTEref\2D\hsqcetgp_40_bucketlist.csv', net=True, sym=False)
# Out:
# C:\Users\Standard\Documents\Python\DECPHA\Analyse.py:87: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ne1 = pd.read_csv( epath, header=1, sep = ', ', usecols=[0, 1, 5])
# C:\Users\Standard\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4033: RuntimeWarning: Invalid value encountered in median
#   r = func(a, **kwargs)
# C:\Users\Standard\Documents\Python\DECPHA\Analyse.py:349: RuntimeWarning: invalid value encountered in less
#   ZZr[iZZ<thresh,i] = 1.0

# %%
affiche2(*Imref, scale=5)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
Analyse.NETMODE = 'mieux'
Im2 = loadStd2D(r"ARTEnew/Results/ARTE3_160816/2D/dipsi2phpr_20_bucketlist.csv", net=True, sym=True)
# Out:
# C:\Users\Standard\Documents\Python\DECPHA\Analyse.py:87: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ne1 = pd.read_csv( epath, header=1, sep = ', ', usecols=[0, 1, 5])

# %%
#affiche(Im1[0],Im2[1],Im2[2], scale=10)
affiche(*Im2, scale=10)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
Analyse.NETMODE = 'mieux'
Im1 = loadStd2D(r"ARTEnew/Results/ARTE1_160816/2D/dipsi2phpr_20_bucketlist.csv", net=True, sym=True)
affiche(*Im1, scale=10)
# Out:
# C:\Users\Standard\Documents\Python\DECPHA\Analyse.py:87: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ne1 = pd.read_csv( epath, header=1, sep = ', ', usecols=[0, 1, 5])
# <img src="data:image/png;base64,..." width="1000">

# %%
affratio(Im2, Im1, scale=0.04)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
#compare("SMARTE/Results/SMARTE6_161123/2D/dipsi2phpr_20_bucketlist.csv", scale=100)

# %%
affsub(Im2, Im1, scale=2)

# %%
#plt.savefig(r"SMARTE/Results/Autres/cleaningcomparenetencore.png", format='png', bbox_inches='tight', transparent = 'true')

# %%
#NETMODE = 'encore'
#afflogratio(Im2, Im1, scale=0.012)

# %%
plt.savefig(r"SMARTE/Results/Ratio2D/cosy_6_4.png", format='png', bbox_inches='tight', transparent = 'true')

# %%
imm = Im2[2]/(Im1[2]+1e-5)
Im1[2].std()

# %%
NETMODE = 'mieux'
ZZ = loadStd2D(r"SMARTE/Results/SMARTE4_161123/2D/cosydfph_10_bucketlist.csv", net=False, sym=False)[2]
ZZ2 = loadStd2D(r"SMARTE/Results/SMARTE4_161123/2D/cosydfph_10_bucketlist.csv", net=True, sym=False)[2]
# Out:
# C:\Users\Standard\Documents\Python\DECPHA\Analyse.py:86: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ne1 = pd.read_csv( epath, header=1, sep = ', ', usecols=[0, 1, 5])
# 10942.6

# %%
plt.hist(np.log(ZZ.ravel()),bins=100)
plt.hist(np.log(ZZ2.ravel()),bins=100)
#ZZ2b = np.log(ZZ2)
#ZZ2b = ZZ2b[np.nonzero(ZZ2b)]
#plt.hist(ZZ2b,bins=100);
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([7.3956e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 6.6600e+02,
#         3.2010e+03, 1.8940e+03, 1.2040e+03, 8.3200e+02, 7.4500e+02,
#         7.5500e+02, 8.7000e+02, 7.7700e+02, 7.4300e+02, 6.1800e+02,
#         3.7900e+02, 2.6800e+02, 3.1800e+02, 3.0200e+02, 2.1700e+02,
# ...

# %%
np.log(np.median(ZZ))

# %%
plt.hist(ZZ2b,bins=100);

# %%
def renorm2D(Z, mu, sigma):
    "renormalise un histogramme"
    lZZ = np.log(Z)
    lZZ = lZZ[np.nonzero(lZZ)]
    lmu = lZZ.mean()
    lsigma = lZZ.std()
    print (lmu,lsigma)
    ZZ = np.log(Z)
    line,col = ZZ.shape
#    for i in range(line):
#        for j in range(col):
#            ZZ[i,j] = (ZZ[i,j]-lmu)*sigma/lsigma + mu
    ZZ = (ZZ-lmu)*sigma/lsigma + mu
    ZZ = np.where(Z==1, 0, ZZ)
    return np.exp(ZZ)

# %%
plt.contour( renorm2D(ZZ2,12,1) )

# %%
rZZ =renorm2D(ZZ2,10,1)
rZZ2b = np.log(rZZ.ravel())
rZZ2b = rZZ2b[np.nonzero(rZZ2b)]
plt.hist(rZZ2b, bins=100);

# %%
rZZ

# %%
affiche(Im2[0], Im2[1], symetrise(rZZ),scale=1)

# %%
min(np.inf,1.0)

# %%
plt.plot(z)

# %%
Im1.shape

# %%
plt.contour?
